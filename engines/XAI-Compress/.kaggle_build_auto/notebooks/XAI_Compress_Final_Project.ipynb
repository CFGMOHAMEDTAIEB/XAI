# %% [markdown]
# ## Problem definition
#
# **THEORETICAL** unless explicitly marked MEASURED below.

# %% [markdown]
# ## Lossless information theory
#
# **THEORETICAL** unless explicitly marked MEASURED below. For bytes $x_1,\ldots,x_n$, $P(x)=\prod_t P(x_t|x_{<t})$.

# %% [markdown]
# ## Entropy
#
# **THEORETICAL** unless explicitly marked MEASURED below.

# %% [markdown]
# ## Cross entropy
#
# **THEORETICAL** unless explicitly marked MEASURED below. $L_{CE}=-N^{-1}\sum_t\log P(x_t|x_{<t})$ and model BPB is $L_{CE}/\ln 2$.

# %% [markdown]
# ## Autoregressive probability
#
# **THEORETICAL** unless explicitly marked MEASURED below.

# %% [markdown]
# ## Bits per byte
#
# **THEORETICAL** unless explicitly marked MEASURED below. MEASURED actual BPB is $8\,|artifact|/|original|$; validation BPB is not artifact BPB.

# %% [markdown]
# ## rANS
#
# **THEORETICAL** unless explicitly marked MEASURED below.

# %% [markdown]
# ## Probability quantization
#
# **THEORETICAL** unless explicitly marked MEASURED below.

# %% [markdown]
# ## GRU architecture
#
# **THEORETICAL** unless explicitly marked MEASURED below.

# %% [markdown]
# ## Transformer architecture
#
# **THEORETICAL** unless explicitly marked MEASURED below.

# %% [markdown]
# ## Numerical stability problem
#
# **THEORETICAL** unless explicitly marked MEASURED below. **MEASURED:** long Transformer runs failed first at `gradient:output.weight`; failed optimizer steps were not executed.

# %% [markdown]
# ## Mathematical stabilization
#
# **THEORETICAL** unless explicitly marked MEASURED below. FP32 attention probabilities/final projection/loss, gradient clipping, bounded AMP recovery, and verified last-stable rollback are used.

# %% [markdown]
# ## Streaming XAIC
#
# **THEORETICAL** unless explicitly marked MEASURED below.

# %% [markdown]
# ## Lossy autoencoder
#
# **THEORETICAL** unless explicitly marked MEASURED below.

# %% [markdown]
# ## Quantized latent
#
# **THEORETICAL** unless explicitly marked MEASURED below.

# %% [markdown]
# ## Latent entropy model
#
# **THEORETICAL** unless explicitly marked MEASURED below.

# %% [markdown]
# ## Rate-distortion theory
#
# **THEORETICAL** unless explicitly marked MEASURED below. Lossy training minimizes $R+\lambda D$; quality must be reported together with bitrate.

# %% [markdown]
# ## PSNR and SSIM
#
# **THEORETICAL** unless explicitly marked MEASURED below.

# %% [markdown]
# ## Benchmark methodology
#
# **THEORETICAL** unless explicitly marked MEASURED below.

# %% [markdown]
# ## Measured results
#
# **THEORETICAL** unless explicitly marked MEASURED below. **MEASURED:** see `results/final_project/*.csv` and `final_status.json`; no missing value is inferred.

# %% [markdown]
# ## Classical comparison
#
# **THEORETICAL** unless explicitly marked MEASURED below.

# %% [markdown]
# ## Pareto analysis
#
# **THEORETICAL** unless explicitly marked MEASURED below.

# %% [markdown]
# ## Limitations
#
# **THEORETICAL** unless explicitly marked MEASURED below. Unmeasured MS-SSIM and unavailable validated Transformer metrics are reported as NOT MEASURED.

# %% [markdown]
# ## Future work
#
# **THEORETICAL** unless explicitly marked MEASURED below.

# %%
import pandas as pd
pd.read_csv('../results/final_project/lossless_benchmark.csv')
